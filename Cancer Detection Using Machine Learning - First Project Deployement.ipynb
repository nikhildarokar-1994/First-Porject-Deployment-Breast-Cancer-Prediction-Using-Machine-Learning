# %% [markdown]
# # Breast Cancer Detection Using Machine Learning Classifier

# %%
# import libraries
import pandas as pd 
import numpy as np 
import matplotlib.pyplot as plt 
import seaborn as sns

# %% [markdown]
# # Data Load

# %%
df = pd.read_csv('data.csv')
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %% [markdown]
# # Data Visualization

# %%
# Paiplot of cancer dataframe
#sns.pairplot(df, hue = 'target')

# %%
# pair plot of sample feature
#sns.pairplot(df, hue = 'target', 
#vars = ['mean radius', 'mean texture', 'mean perimeter', 'mean area', 'mean smoothness'] ) # ****** img 5 ***

# %%
# Count the target class
#sns.countplot(df['target']) #  **************************** img 5 *************************

# %%
# counter plot of feature mean radius
#plt.figure(figsize = (20,8))
#sns.countplot(df['mean radius']) # *** img 7 ****

# %% [markdown]
# # Heatmap

# %%
# heatmap of DataFrame
#plt.figure(figsize=(16,9))
#sns.heatmap(df) # **** img 8 ****

# %% [markdown]
# ##  Heatmap of a correlation matrix

# %%
#df.corr()

# %%
# Heatmap of Correlation matrix of breast cancer DataFrame
#plt.figure(figsize=(20,20))
#sns.heatmap(df.corr(), annot = True, cmap ='coolwarm', linewidths=2) # *** img 9 ***

# %%
df.head()
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  \
# 0    842302         M        17.99         10.38          122.80     1001.0
# 1    842517         M        20.57         17.77          132.90     1326.0
# 2  84300903         M        19.69         21.25          130.00     1203.0
# 3  84348301         M        11.42         20.38           77.58      386.1
# 4  84358402         M        20.29         14.34          135.10     1297.0
#
#    smoothness_mean  compactness_mean  concavity_mean  concave points_mean  \
# 0          0.11840           0.27760          0.3001              0.14710
# 1          0.08474           0.07864          0.0869              0.07017
# 2          0.10960           0.15990          0.1974              0.12790
# 3          0.14250           0.28390          0.2414              0.10520
# 4          0.10030           0.13280          0.1980              0.10430
#
# ...

# %%
# create second DataFrame by droping target
df1 = df.drop(['diagnosis','id'], axis = 1)
print("The shape of 'cancer_df2' is : ", df1.shape)
# Out:
# The shape of 'cancer_df2' is :  (569, 30)

# %%
#df1.corrwith(cancer_df.target)

# %%
# visualize correlation barplot
#plt.figure(figsize = (16,5))
#ax = sns.barplot(df1.corrwith(cancer_df.target).index,df1.corrwith(cancer_df.target))
#ax.tick_params(labelrotation = 90) # **** img 10 ***

# %% [markdown]
# # Split DatFrame in Train and Test

# %%
# input variable
X = df.drop(['diagnosis','id'], axis = 1) 
X.head(6)
# Out:
#    radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 0        17.99         10.38          122.80     1001.0          0.11840
# 1        20.57         17.77          132.90     1326.0          0.08474
# 2        19.69         21.25          130.00     1203.0          0.10960
# 3        11.42         20.38           77.58      386.1          0.14250
# 4        20.29         14.34          135.10     1297.0          0.10030
# 5        12.45         15.70           82.57      477.1          0.12780
#
#    compactness_mean  concavity_mean  concave points_mean  symmetry_mean  \
# 0           0.27760          0.3001              0.14710         0.2419
# 1           0.07864          0.0869              0.07017         0.1812
# 2           0.15990          0.1974              0.12790         0.2069
# 3           0.28390          0.2414              0.10520         0.2597
# 4           0.13280          0.1980              0.10430         0.1809
# ...

# %%
# output variable
y = df['diagnosis'] 
y.head(6)
# Out:
# 0    M
# 1    M
# 2    M
# 3    M
# 4    M
# 5    M
# Name: diagnosis, dtype: object

# %% [markdown]
# ## LabelEncoding

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
y = le.fit_transform(df['diagnosis']) 
y = pd.Series(y)
y.head()
# Out:
# 0    1
# 1    1
# 2    1
# 3    1
# 4    1
# dtype: int32

# %%
# split dataset into train and test
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state= 5)

# %%
X_train
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 306       13.200         15.82           84.07      537.3          0.08511
# 410       11.360         17.57           72.49      399.8          0.08858
# 197       18.080         21.84          117.40     1024.0          0.07371
# 376       10.570         20.22           70.15      338.3          0.09073
# 244       19.400         23.50          129.10     1155.0          0.10270
# ..           ...           ...             ...        ...              ...
# 8         13.000         21.82           87.50      519.8          0.12730
# 73        13.800         15.79           90.43      584.1          0.10070
# 400       17.910         21.02          124.40      994.0          0.12300
# 118       15.780         22.91          105.70      782.6          0.11550
# 206        9.876         17.27           62.92      295.4          0.10890
#
# ...

# %%
X_test
# Out:
#      radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  \
# 28         15.30         25.27          102.40      732.4          0.10820
# 163        12.34         22.22           79.85      464.5          0.10120
# 123        14.50         10.89           94.28      640.7          0.11010
# 361        13.30         21.57           85.24      546.1          0.08582
# 549        10.82         24.21           68.89      361.6          0.08192
# ..           ...           ...             ...        ...              ...
# 414        15.13         29.81           96.71      719.5          0.08320
# 515        11.34         18.61           72.76      391.2          0.10490
# 186        18.31         18.58          118.60     1041.0          0.08588
# 3          11.42         20.38           77.58      386.1          0.14250
# 261        17.35         23.06          111.00      933.1          0.08662
#
# ...

# %%
y_train
# Out:
# 306    0
# 410    0
# 197    1
# 376    0
# 244    1
#       ..
# 8      1
# 73     1
# 400    1
# 118    1
# 206    0
# Length: 455, dtype: int32

# %%
y_test
# Out:
# 28     1
# 163    0
# 123    0
# 361    0
# 549    0
#       ..
# 414    1
# 515    0
# 186    1
# 3      1
# 261    1
# Length: 114, dtype: int32

# %% [markdown]
# # Feature scaling

# %%
from sklearn.preprocessing import Normalizer
nm = Normalizer()
X_train_nm = nm.fit_transform(X_train)
X_test_nm = nm.transform(X_test)

# %% [markdown]
# # Machine Learning Model Building

# %%
from sklearn.metrics import confusion_matrix, classification_report, accuracy_score

# %% [markdown]
#  # Random Forest Classifier

# %%
# Random Forest Classifier
from sklearn.ensemble import RandomForestClassifier
rf_classifier = RandomForestClassifier(n_estimators = 20, criterion = 'entropy', random_state = 51)
rf_classifier.fit(X_train, y_train)
y_pred_rf = rf_classifier.predict(X_test)
accuracy_score(y_test, y_pred_rf)
# Out:
# 0.9736842105263158

# %% [markdown]
# # Save Random Forest Classifier model using Pickel

# %%
## Pickle
import pickle

# save model
pickle.dump(rf_classifier, open('model.pickle', 'wb'))

# load model
Model = pickle.load(open('model.pickle', 'rb'))

# predict the output
y_pred = Model.predict(X_test)

# confusion matrix
print('Confusion matrix of Random_Forest_classifier model: \n',confusion_matrix(y_test, y_pred),'\n')

# show the accuracy
print('Accuracy of Random_Forest_classifier model = ',accuracy_score(y_test, y_pred))
# Out:
# Confusion matrix of Random_Forest_classifier model:
#  [[66  0]
#  [ 3 45]]
#
# Accuracy of Random_Forest_classifier model =  0.9736842105263158

# %%
len(Model.predict(X))
# Out:
# 569

# %%
len(y)
# Out:
# 569

# %%
accuracy_score(y,Model.predict(X))
# Out:
# 0.9929701230228472
